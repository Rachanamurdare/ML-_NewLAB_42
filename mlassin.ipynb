# %%
# !pip install pandas

# %%
>>> import pandas as pd
>>> import numpy as np

# %%
df = pd.read_csv("C:\\Users\\Rachana\\Downloads\\holidays_events.csv")

# %%
df.head(5)
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB

# %%
to_drop = ['locale']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale_name  350 non-null    object
#  3   description  350 non-null    object
#  4   transferred  350 non-null    bool
# dtypes: bool(1), object(4)
# memory usage: 11.4+ KB

# %%
df.head(20)
# Out:
#           date     type    locale_name                    description  \
# 0   2012-03-02  Holiday          Manta             Fundacion de Manta
# 1   2012-04-01  Holiday       Cotopaxi  Provincializacion de Cotopaxi
# 2   2012-04-12  Holiday         Cuenca            Fundacion de Cuenca
# 3   2012-04-14  Holiday       Libertad      Cantonizacion de Libertad
# 4   2012-04-21  Holiday       Riobamba      Cantonizacion de Riobamba
# 5   2012-05-12  Holiday           Puyo         Cantonizacion del Puyo
# 6   2012-06-23  Holiday       Guaranda      Cantonizacion de Guaranda
# 7   2012-06-25  Holiday       Imbabura  Provincializacion de Imbabura
# 8   2012-06-25  Holiday      Latacunga     Cantonizacion de Latacunga
# 9   2012-06-25  Holiday        Machala           Fundacion de Machala
# 10  2012-07-03  Holiday  Santo Domingo     Fundacion de Santo Domingo
# 11  2012-07-03  Holiday      El Carmen     Cantonizacion de El Carmen
# ...

# %%
df.loc[90]
# Out:
# date           2013-12-26
# type           Additional
# locale_name       Ecuador
# description     Navidad+1
# transferred         False
# Name: 90, dtype: object

# %%
df.tail()
# Out:
#            date        type locale_name description  transferred
# 345  2017-12-22  Additional     Ecuador   Navidad-3        False
# 346  2017-12-23  Additional     Ecuador   Navidad-2        False
# 347  2017-12-24  Additional     Ecuador   Navidad-1        False
# 348  2017-12-25     Holiday     Ecuador     Navidad        False
# 349  2017-12-26  Additional     Ecuador   Navidad+1        False

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# Length: 350, dtype: bool

# %%
df.isnull()
# Out:
#       date   type  locale_name  description  transferred
# 0    False  False        False        False        False
# 1    False  False        False        False        False
# 2    False  False        False        False        False
# 3    False  False        False        False        False
# 4    False  False        False        False        False
# ..     ...    ...          ...          ...          ...
# 345  False  False        False        False        False
# 346  False  False        False        False        False
# 347  False  False        False        False        False
# 348  False  False        False        False        False
# 349  False  False        False        False        False
#
# [350 rows x 5 columns]

# %%
df.loc[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [date, type, locale_name, description, transferred]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale_name  350 non-null    object
#  3   description  350 non-null    object
#  4   transferred  350 non-null    bool
# dtypes: bool(1), object(4)
# memory usage: 11.4+ KB
